# %%
import requests as rq
from bs4 import BeautifulSoup as bs
import numpy as np
import pandas as pd

openAPI = 'http://openapi.data.go.kr/openapi/service/rest/Covid19/getCovid19InfStateJson?serviceKey=iXBz6vLDZDiJpGqVOnREzNkdpPS00YhaGTcMHJJgXQEajlD5GmUTV0SrtedSbZf%2FsNfUyG%2B2iXgcU7bAkwyUcg%3D%3D&pageNo=1&numOfRows=10&startCreateDt=20200201&endCreateDt=20201031'
res = rq.get(openAPI)
soup = bs(res.content, 'html.parser')
soup

infoCOVID19 = soup.findAll('item')

date=[]
decidecnt=[]
clearcnt=[]
deathcnt=[]
newDecidecnt=[]

for data in infoCOVID19:
# Out:
# "\ninfoCOVID19 = soup.findAll('item')\n\ndate=[]\ndecidecnt=[]\nclearcnt=[]\ndeathcnt=[]\nnewDecidecnt=[]\n\nfor data in infoCOVID19:\n    "
