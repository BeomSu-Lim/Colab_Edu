# %% [markdown]
# 아래의 블로그를 참조하였습니다.<br>
# https://m.blog.naver.com/samsjang/221006905415

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures

# %%
X = np.array([258.0, 270.0, 294.0, 320.0, 342.0,
              368.0, 396.0, 446.0, 480.0, 586.0])[:, np.newaxis]
y = np.array([236.4, 234.4, 252.8, 298.6, 314.2,
              342.2, 360.8, 368.0, 391.2, 390.9])


lr=LinearRegression()
pr=LinearRegression()

quadratic = PolynomialFeatures(degree=2)
X_quad = quadratic.fit_transform(X)

lr.fit(X, y)
X_fit = np.arange(250, 600, 10)[:, np.newaxis]
y_lin_fit = lr.predict(X_fit)

pr.fit(X_quad, y)
y_quad_fit = pr.predict(quadratic.fit_transform(X_fit))

y_lin_pred = lr.predict(X)
y_quad_pred = pr.predict(X_quad)

mse_lin = mean_squared_error(y, y_lin_pred)
mse_quad = mean_squared_error(y, y_quad_pred)

re_lin = r2_score(y, y_lin_pred)
r2_quad = r2_score(y, y_quad_pred)

print('MSE\tLinear : %.2f, \tQuadratic : %.2f' %(mse_lin, mse_quad))
print('R2\tLinear : %.2f, \tQuadratic : %.2f' %(re_lin, r2_quad))
# Out:
# MSE	Linear : 568.95, 	Quadratic : 61.35
# R1	Linear : 0.83, 	Quadratic : 0.98

# %%
plt.scatter(X, y)
plt.plot(X_fit, y_lin_fit, 'g--', label='linear fit', )
plt.plot(X_fit, y_quad_fit, 'b-', label='quadratic fit' )
plt.legend()
plt.show()
